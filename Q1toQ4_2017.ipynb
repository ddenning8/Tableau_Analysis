# %%
import pandas as pd

# %%
Q1_2017 = pd.read_csv("Resources/Q1_2017.csv")
Q2_2017 = pd.read_csv("Resources/Q2_2017.csv")
Q3_2017 = pd.read_csv("Resources/Q3_2017.csv")
Q4_2017 = pd.read_csv("Resources/Q4_2017.csv")

# %%
Q1_2017.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/17                                              16009
# 1  1/2/17                                               8921
# 2  1/3/17                                              14198
# 3  1/4/17                                              34039
# 4  1/5/17                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
Q1_2017 = Q1_2017[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q1_2017.head()
# Out:
#      Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  1/1/17                                             1237
# 1  1/2/17                                              142
# 2  1/3/17                                               42
# 3  1/4/17                                              475
# 4  1/5/17                                              214
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                             33
# 1                                             15
# 2                                             15
# 3                                             29
# 4                                             17

# %%
Q2_2017 = Q2_2017[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q2_2017.head()
# Out:
#      Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  4/1/17                                              767
# 1  4/2/17                                             3639
# 2  4/3/17                                              970
# 3  4/4/17                                              183
# 4  4/5/17                                             1192
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                             43
# 1                                             58
# 2                                             68
# 3                                             23
# 4                                             59

# %%
Q3_2017 = Q3_2017[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q3_2017.head()
# Out:
#      Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  7/1/17                                             2828
# 1  7/2/17                                             4314
# 2  7/3/17                                             3243
# 3  7/4/17                                             4929
# 4  7/5/17                                             1886
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            372
# 1                                            458
# 2                                            316
# 3                                            315
# 4                                            267

# %%
Q4_2017 = Q4_2017[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q4_2017.head()
# Out:
#       Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  10/1/17                                             3511
# 1  10/2/17                                             1408
# 2  10/3/17                                             1258
# 3  10/4/17                                             1377
# 4  10/5/17                                             1365
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            235
# 1                                            242
# 2                                            194
# 3                                            188
# 4                                            251

# %%
Q1Q4_2017_frames = [Q1_2017, Q2_2017, Q3_2017, Q4_2017]

data_2017 = pd.concat(Q1Q4_2017_frames)

# %%
data_2017.head()
# Out:
#      Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  1/1/17                                             1237
# 1  1/2/17                                              142
# 2  1/3/17                                               42
# 3  1/4/17                                              475
# 4  1/5/17                                              214
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                             33
# 1                                             15
# 2                                             15
# 3                                             29
# 4                                             17

# %%
data_2017.count()
# Out:
# Date                                               365
# 24-Hour Passes Purchased (midnight to 11:59 pm)    365
# 3-Day Passes Purchased (midnight to 11:59 pm)      365
# dtype: int64

# %%
data_2017.to_csv("Q1Q4_data_2017.csv", index=False)
