# %%
import pandas as pd

# %%
Q1_2018 = pd.read_csv("Resources/Q1_2018.csv")
Q2_2018 = pd.read_csv("Resources/Q2_2018.csv")
Q3_2018 = pd.read_csv("Resources/Q3_2018.csv")
Q4_2018 = pd.read_csv("Resources/Q4_2018.csv")

# %%
Q1_2018.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/2018                                               5499
# 1  1/2/2018                                              18818
# 2  1/3/2018                                              24299
# 3  1/4/2018                                               1922
# 4  1/5/2018                                               4972
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        11483
# 1                                        39352
# 2                                        42853
# 3                                         5328
# 4                                        14303
#
#    Total Annual Members (All Time)  \
# 0                           253490
# 1                           253558
# 2                           253591
# 3                           253604
# 4                           253614
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
Q1_2018 = Q1_2018[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q1_2018.head()
# Out:
#        Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  1/1/2018                                              123
# 1  1/2/2018                                              125
# 2  1/3/2018                                              164
# 3  1/4/2018                                                2
# 4  1/5/2018                                               14
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                              7
# 1                                             12
# 2                                              4
# 3                                              1
# 4                                              0

# %%
Q2_2018 = Q2_2018[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q2_2018.head()
# Out:
#      Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  4/1/18                                             2363
# 1  4/2/18                                              297
# 2  4/3/18                                              189
# 3  4/4/18                                              611
# 4  4/5/18                                              972
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            264
# 1                                             20
# 2                                             21
# 3                                             48
# 4                                            112

# %%
Q3_2018 = Q3_2018[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q3_2018.head()
# Out:
#      Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  7/1/18                                             4209
# 1  7/2/18                                             2702
# 2  7/3/18                                             2358
# 3  7/4/18                                             5662
# 4  7/5/18                                             3344
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            211
# 1                                            241
# 2                                            199
# 3                                            250
# 4                                            264

# %%
Q4_2018 = Q4_2018[['Date','24-Hour Passes Purchased (midnight to 11:59 pm)','3-Day Passes Purchased (midnight to 11:59 pm)']]
Q4_2018.head()
# Out:
#       Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  10/1/18                                             2618
# 1  10/2/18                                             2666
# 2  10/3/18                                             3141
# 3  10/4/18                                             2838
# 4  10/5/18                                             3979
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            307
# 1                                            195
# 2                                            199
# 3                                            222
# 4                                            254

# %%
Q1Q4_2018_frames = [Q1_2018, Q2_2018, Q3_2018, Q4_2018]

data_2018 = pd.concat(Q1Q4_2018_frames)

# %%
data_2018.head()
# Out:
#        Date  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  1/1/2018                                              123
# 1  1/2/2018                                              125
# 2  1/3/2018                                              164
# 3  1/4/2018                                                2
# 4  1/5/2018                                               14
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                              7
# 1                                             12
# 2                                              4
# 3                                              1
# 4                                              0

# %%
data_2018.count()
# Out:
# Date                                               365
# 24-Hour Passes Purchased (midnight to 11:59 pm)    365
# 3-Day Passes Purchased (midnight to 11:59 pm)      365
# dtype: int64

# %%
data_2018.to_csv("Q1Q4_data_2018.csv", index=False)
