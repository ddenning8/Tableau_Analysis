# %%
import pandas as pd

# %%
dec_2018 = pd.read_csv("Resources/Dec_4_2018_Data.csv")

# %%
dec_2018.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           254  2018-11-01 00:00:12.9100  2018-11-01 00:04:27.3870
# 1           833  2018-11-01 00:00:16.3440  2018-11-01 00:14:09.4320
# 2           683  2018-11-01 00:00:17.6630  2018-11-01 00:11:40.9170
# 3          1840  2018-11-01 00:00:18.7970  2018-11-01 00:30:59.3050
# 4          1212  2018-11-01 00:00:47.3230  2018-11-01 00:20:59.8840
# 5           792  2018-11-01 00:01:07.6490  2018-11-01 00:14:20.1120
# 6           243  2018-11-01 00:01:12.1010  2018-11-01 00:05:15.3940
# 7           460  2018-11-01 00:01:12.4060  2018-11-01 00:08:53.2740
# 8           778  2018-11-01 00:01:14.6240  2018-11-01 00:14:13.3190
# 9           178  2018-11-01 00:01:32.0970  2018-11-01 00:04:30.1980
#
#    start station id            start station name  start station latitude  \
# 0            3522.0                37 St & 24 Ave               40.770148
# ...

# %%
dec_2018.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
dec_2018.count()
# Out:
# tripduration               1260355
# starttime                  1260355
# stoptime                   1260355
# start station id           1260275
# start station name         1260275
# start station latitude     1260355
# start station longitude    1260355
# end station id             1260275
# end station name           1260275
# end station latitude       1260355
# end station longitude      1260355
# bikeid                     1260355
# usertype                   1260355
# birth year                 1260355
# gender                     1260355
# dtype: int64

# %%
dec_2018['birth year'].min()
# Out:
# 1885

# %%
dec_2018['birth year'].max()
# Out:
# 2002

# %%
dec_2018 = dec_2018[~(dec_2018['birth year'] < 1960)]

# %%
dec_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           254  2018-11-01 00:00:12.9100  2018-11-01 00:04:27.3870
# 1           833  2018-11-01 00:00:16.3440  2018-11-01 00:14:09.4320
# 2           683  2018-11-01 00:00:17.6630  2018-11-01 00:11:40.9170
# 3          1840  2018-11-01 00:00:18.7970  2018-11-01 00:30:59.3050
# 4          1212  2018-11-01 00:00:47.3230  2018-11-01 00:20:59.8840
#
#    start station id            start station name  start station latitude  \
# 0            3522.0                37 St & 24 Ave               40.770148
# 1             252.0  MacDougal St & Washington Sq               40.732264
# 2            3405.0                  5 St & 6 Ave               40.670484
# 3            3150.0            E 85 St & York Ave               40.775369
# 4             325.0               E 19 St & 3 Ave               40.736245
#
#    start station longitude  end station id             end station name  \
# ...

# %%
dec_2018.count()
# Out:
# tripduration               1178010
# starttime                  1178010
# stoptime                   1178010
# start station id           1177930
# start station name         1177930
# start station latitude     1178010
# start station longitude    1178010
# end station id             1177930
# end station name           1177930
# end station latitude       1178010
# end station longitude      1178010
# bikeid                     1178010
# usertype                   1178010
# birth year                 1178010
# gender                     1178010
# dtype: int64

# %%
dec_2018 = dec_2018.dropna(how='any',axis=0)

# %%
dec_2018.count()
# Out:
# tripduration               1177930
# starttime                  1177930
# stoptime                   1177930
# start station id           1177930
# start station name         1177930
# start station latitude     1177930
# start station longitude    1177930
# end station id             1177930
# end station name           1177930
# end station latitude       1177930
# end station longitude      1177930
# bikeid                     1177930
# usertype                   1177930
# birth year                 1177930
# gender                     1177930
# dtype: int64

# %%
dec_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           254  2018-11-01 00:00:12.9100  2018-11-01 00:04:27.3870
# 1           833  2018-11-01 00:00:16.3440  2018-11-01 00:14:09.4320
# 2           683  2018-11-01 00:00:17.6630  2018-11-01 00:11:40.9170
# 3          1840  2018-11-01 00:00:18.7970  2018-11-01 00:30:59.3050
# 4          1212  2018-11-01 00:00:47.3230  2018-11-01 00:20:59.8840
#
#    start station id            start station name  start station latitude  \
# 0            3522.0                37 St & 24 Ave               40.770148
# 1             252.0  MacDougal St & Washington Sq               40.732264
# 2            3405.0                  5 St & 6 Ave               40.670484
# 3            3150.0            E 85 St & York Ave               40.775369
# 4             325.0               E 19 St & 3 Ave               40.736245
#
#    start station longitude  end station id             end station name  \
# ...

# %%
dec_2018.to_csv("dec_2018.csv", index=False)
